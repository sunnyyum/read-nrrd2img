# %% [markdown]
# In this notebook, we will read and display grayscale image nrrd file

# %%
import os.path as path
import sys
sys.path.insert(0, path.abspath('../'))
import nrrd_handler
import urllib.request
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# First, we download the nrrd file. Downloading the file could take some time. <br> You can also manually download the file in http://teem.sourceforge.net/nrrd/files/fool.nrrd

# %%
file_path = './fool.nrrd'

# %%
if not path.exists(file_path):
    urllib.request.urlretrieve("http://teem.sourceforge.net/nrrd/files/fool.nrrd", file_path)

# %% [markdown]
# Initialize the file path

# %%
nH = nrrd_handler.NrrdHandler(file_path)

# %% [markdown]
# Decode the file using pynrrd library and SimpleITK library

# %%
img_pynrrd = nH.read_by_pynrrd()
img_sitk = nH.read_by_sitk()

# %% [markdown]
# pynrrd library

# %%
plt.imshow(img_pynrrd)

# %% [markdown]
# SimpleITK

# %%
plt.imshow(img_sitk)
